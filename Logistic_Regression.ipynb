# %% [markdown]
# <a href="https://colab.research.google.com/github/SAVCHink2042/ML-algorithm/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Датасет https://www.kaggle.com/datasets/dragonheir/logistic-regression

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
data = pd.read_csv("Social_Network_Ads.csv")

data['Gender'] = data['Gender'].map({'Male': 1, 'Female': 0})

matrix = data.iloc[:, :4]
target = data.iloc[:,  4]

x_train, x_test, y_train, y_test = train_test_split(matrix, target, test_size = 0.25 )

model = LogisticRegression()
model.fit(x_train, y_train)


y_pred = model.predict(x_test)
y_pred_proba = model.predict_proba(x_test)[:, 1]

print( y_pred_proba )
# Out:
# [9.92406725e-01 8.43261830e-04 8.27227010e-03 6.71695337e-03
#  2.90277451e-02 1.41112884e-01 2.56019998e-01 9.98664322e-01
#  2.51136069e-03 1.89754693e-02 2.78291198e-01 1.37280169e-03
#  1.60497167e-02 4.98857381e-01 9.19434454e-01 9.64920660e-01
#  1.10041146e-02 9.76299169e-01 7.63497383e-01 4.09068307e-03
#  9.29801618e-01 2.70521386e-01 2.59435603e-02 2.89331952e-01
#  9.65560534e-01 7.48518635e-02 2.06811760e-02 9.27109461e-01
#  6.05823750e-01 5.50348337e-03 1.09388558e-03 9.95390213e-01
#  2.43815769e-01 8.26559430e-01 3.28643478e-01 9.55973153e-01
#  2.10013477e-01 7.14786923e-03 2.25649082e-03 6.76223972e-01
#  4.85210387e-01 7.59071151e-01 3.43867536e-01 1.47456696e-02
#  2.99700143e-02 6.04072354e-03 8.19175670e-01 3.85686086e-01
#  9.85508415e-01 1.50362389e-02 9.93446407e-01 1.49511485e-01
#  7.71123907e-01 4.93103664e-02 1.41617112e-01 4.24716298e-01
#  2.77428289e-02 1.38071125e-01 9.49304968e-03 3.59554454e-01
# ...

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = roc_auc_score(y_test, y_pred_proba)

print(roc_auc)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr,  lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot(np.linspace(0,1, 2), np.linspace(0,1,2), label = 'y=x' )
plt.legend()
plt.show()
# Out:
# 0.919120879120879
